# %%
# Cell 1: Setup
# !git clone https://github.com/Tamil05t/specter-network-scanner.git
# %cd specter-network-scanner

# %%
# Cell 2: Install dependencies
# !pip install -r requirements.txt

# %%
# Cell 3: Run demo scan on safe public target
# !python main.py scan -t scanme.nmap.org --ports 22,80 --exploit-lookup

# %%
# Cell 4: Generate HTML report
# !python main.py scan -t scanme.nmap.org --ports 22,80 --format html

# %%
# Cell 5: Display HTML report
from IPython.display import HTML, display
import glob
import os

# Find the latest HTML report
reports = glob.glob('reports/*.html')
if reports:
    latest = max(reports, key=os.path.getctime)
    display(HTML(f'<iframe src="{latest}" width="100%" height="600"></iframe>'))
else:
    print("No report found")
